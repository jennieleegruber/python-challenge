# %%
# Define the function and have it accept the 'financial_data' as its sole parameter
def financial_summary(fin_data):
    total_months = int(fin_data[0])
    total_pl = float(fin_data[1])
    monthly_change = (fin_data[2])
    average_change = float(fin_data[3])
    greatest_increase = float(fin_data[4])
    greatest_decrease = float(fin_data[5])
    profit_month_name = str(fin_data[6])
    loss_month_name = str(fin_data[7])

    # Total months can be found by skipping the header and counting total rows in the csvfile
    total_months += 1

    # Total profits and losses over given time period can be found by summing each month's profits or losses
    total_pl = sum(row[1])
    
    # Monthly change can be found by taking the difference of the next value from the prevoius value in the profit loss column
    monthly_change = ??? 

    # Average change in profits and losses per month can be found by taking the sum of all the differneces as the change of each month and dividing by the total number of months
    average_change = sum(monthly_change)/ total_months 
    
    # Greatest profit can be found by identify the maximum value in the profit/loss colummn
    greatest_increase = [row[1] if row[1] > greatest increase]
    
    # Greatest loss can be found by identify the minimum value in the profit/loss colummn
    greatest_decrease = [row[1] if row[1] < greatest increase]
    
    # Profit month name can be found by 
    profit_month_name = [row[0] if row[1] > greatest increase]
    
    # Loss month name can be found by 
    loss_month_name = [row[0] if row[1] < greatest increase]

    # Print out the financial summary with profit/loss stats
    print(f"Total Months: {int(total_months)")
    print(f"Total: {float(total_pl)}")
    print(f"Average  Change: ${float(average_change)}")
    print(f"Greatest Increase in Profits: {str(profit_month_name)},{float(greatest_increase)}")
    print(f"Greatest Loss in Profits: {str(loss_month_name)},{float(greatest_decrease)}")

# Read in the CSV file
with open(bank_path, 'r') as csvfile:

    # Split the data on commas
    csvreader = csv.reader(csvfile, delimiter=',')

    header = next(csvreader)
    total_months = 0
    total_pl = 0
    monthly_change = 0
    average_change = 0
    greatest_increase = 0
    greatest_decrease = 0
    profit_month_name = 0
    loss_month_name = 0

    # Loop through the data
    for row in csvreader:
        print(def(financial_summary))
        
—————————————

import csv
import os

voter_path = "Resources/election_data.csv"

with open(voter_path) as csvfile: 
    csvreader = csv.reader(csvfile, delimiter=",")

## def voting_info():
    total_votes = float
    final_candidate_list = []
    candidate_vote_count = []
    candidate_percent = []
    winner_name = string
    winner_votes = float

candidate_info = {}

print(f'[{str(candy_list.index(candy))}] {candy}')

    
def poll_summary(): 
    print("Election Results")
    print("----------------")
    print(f'"Total votes: " {total_votes}')
    for canidate in range[0,(len(final_candidate_list))]: 
        print(f'{(candidate_names[0])}" : "{(candidate_percent[0])} "% " {(candidate_vote_count[0])}')
    for candidate in range[0,len(final_candidate_list)]: 
        if float(candidate_vote_count[0]) >= float(winner_votes[])
            winner_name = str(final_candidate_list[0])
            winner_votes = candidate_vote_count[0]
    print("----------------")
    print(f'"Winner: " {winner_name})
    print("----------------")
        

# to print all candidates identify when candidate changes in the data set and print at the change, using an x to ensure on unique items are added to the array

# to print candidate voter count use a conditional to add one to the count if the candidate matches the candidate being counted, to do this create a dictionary that ties each candidate to a their vote count

# to print the candidate % of the vote, expand on the definition to include an additional attribute, the percentage of votes. Do this by taking the existing voter count of each candidate and dividing it by the total votes

# to print the winner pass a conditional an array that sets the first candidate in the array as the winner, then iterates through the array moving the next canidate to the winner column if the vote count is greater than the current winner


for row in csvread: 
    #skip first row of the data set
    ????
    
    #count the number of votes in the data 
    total_votes = total_votes + 1
    
    # to print all candidates identify when candidate changes in the data set and print at the change, using an x to ensure on unique items are added to the array          
          final_candidate_list.append(str(row[2]) if row[2] != row[2])
    
    
    # to print candidate voter count use a conditional to add one to the count if the candidate matches the candidate being counted, to do this create a dictionary that ties each candidate to a their vote count
    candidate_votes.append(float[])
    
    # to print the candidate % of the vote, expand on the definition to include an additional attribute, the percentage of votes. Do this by taking the existing voter count of each candidate and dividing it by the total votes
    candidate_percent = round(float(row[0]) / total_votes, 3)
    
    # to print the winner pass a conditional an array that sets the first candidate in the array as the winner, then iterates through the array moving the next canidate to the winner column if the vote count is greater than the current winner

print(poll_summary(voting_info))
# Out:
#   File "<ipython-input-1-78567e7d2a95>", line 19
#     monthly_change = ???
#                      ^
# SyntaxError: invalid syntax
